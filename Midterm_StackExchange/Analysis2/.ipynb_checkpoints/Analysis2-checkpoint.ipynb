# %%
import requests
import csv
import sys
import os
import json
sys.path.append(os.path.abspath('../Analysis1'))
from Analysis1_question_userid import user_ids

user_profile = {}
abs_path = os.path.abspath("../Analysis1/data")
listJsonFiles = os.listdir(abs_path)
for file in listJsonFiles:
    with open(abs_path + '/' + file) as jsonfile:
        jsonData = json.load(jsonfile)
        for item in jsonData["items"]:
            user_id = item["owner"]["user_id"]
            if not user_id in user_profile:
                user_profile[user_id] = dict((k, item["owner"][k]) for k in ("user_id", "display_name","link","reputation"))

# %%
# make requests of each user_id in user/{ids}/tags, and get tags 
user_ids_distinct = list(set(user_ids)) #425
for i in user_ids_distinct:
    userid_str = str(i)
    key = '1N2)WAQaEFzyJP*F)Al2Kw(('
    url = 'https://api.stackexchange.com/2.2/users/{}/tags?key={}\
    &order=desc&sort=popular&site=stackoverflow'.format(userid_str,key)
    r = requests.get(url)
    items = r.json()["items"]
    tags = list()
    for item in items:
        tag = item["name"]
        tags.append(tag)
    user_profile[i]['tags'] = tags

# %%
user_profile_sorted = sorted(user_profile.items(), key = lambda item: item[1]["reputation"], reverse=True)
print(user_profile_sorted)
# Out:
# [(3510736, {'user_id': 3510736, 'display_name': 'Ami Tavory', 'tags': ['python', 'c++', 'pandas', 'algorithm', 'numpy', 'c++11', 'dataframe', 'scikit-learn', 'arrays', 'machine-learning', 'multithreading', 'templates', 'sorting', 'list', 'stl', 'string', 'dictionary', 'python-2.7', 'data-structures', 'scipy', 'graph', 'vector', 'csv', 'performance', 'python-3.x', 'time-complexity', 'big-o', 'class', 'tree', 'matplotlib'], 'link': 'http://stackoverflow.com/users/3510736/ami-tavory', 'reputation': 35841}), (2336654, {'user_id': 2336654, 'display_name': 'piRSquared', 'tags': ['pandas', 'python', 'dataframe', 'numpy', 'python-3.x', 'python-2.7', 'multi-index', 'datetime', 'csv', 'group-by', 'matplotlib', 'series', 'indexing', 'string', 'merge', 'dictionary', 'regex', 'scipy', 'list', 'multiple-columns', 'nan', 'pivot-table', 'scikit-learn', 'time-series', 'plot', 'performance', 'pivot', 'matrix', 'excel', 'jupyter-notebook'], 'link': 'http://stackoverflow.com/users/2336654/pirsquared', 'reputation': 30103}), (2411320, {'user_id': 2411320, 'display_name': 'gsamaras', 'tags': ['c++', 'c', 'python', 'apache-spark', 'distributed-computing', 'arrays', 'c++11', 'algorithm', 'pointers', 'html', 'string', 'nearest-neighbor', 'javascript', 'css', 'bigdata', 'function', 'linux', 'jquery', 'css3', 'mpi', 'file', 'list', 'io', 'hadoop', 'struct', 'vector', 'scala', 'machine-learning', 'computational-geometry', 'class'], 'link': 'http://stackoverflow.com/users/2411320/gsamaras', 'reputation': 20310}), (1179880, {'user_id': 1179880, 'display_name': 'whytheq', 'tags': ['mdx', 'ssas', 'sql-server', 'sql', 'excel', 'excel-vba', 'c#', 'vba', 'olap', 'reporting-services', 'tsql', 'sql-server-2008-r2', 'winforms', 'olap-cube', 'mondrian', 'python', 'sql-server-2012', 'cube', 'vb.net', 'sql-server-2008', 'visual-studio-2010', 'vim', 'javascript', 'excel-2010', 'filter', 'pandas', 'visual-studio', 'd3.js', 'ssas-2012', 'ssas-2008'], 'link': 'http://stackoverflow.com/users/1179880/whytheq', 'reputation': 14742}), (194000, {'user_id': 194000, 'display_name': 'Richard', 'tags': ['javascript', 'python', 'django', 'd3.js', 'pandas', 'postgresql', 'css', 'jquery', 'backbone.js', 'google-bigquery', 'sql', 'git', 'angularjs', 'highcharts', 'django-rest-framework', 'github', 'twitter-bootstrap', 'node.js', 'regex', 'osx', 'google-maps', 'google-maps-api-3', 'mapbox', 'leaflet', 'matplotlib', 'html', 'browserify', 'django-models', 'google-cloud-datalab', 'json'], 'link': 'http://stackoverflow.com/users/194000/richard', 'reputation': 11039}), (1231450, {'user_id': 1231450, 'display_name': 'Jan', 'tags': ['regex', 'php', 'python', 'javascript', 'mysql', 'string', 'html', 'jquery', 'preg-replace', 'java', 'arrays', 'preg-match', 'python-3.x', 'c#', 'xml', '.htaccess', 'python-2.7', 'pandas', 'mod-rewrite', 'codeigniter', 'notepad++', 'parsing', 'wordpress', 'web-scraping', 'perl', 'redirect', 'replace', 'apache', 'forms', 'pcre'], 'link': 'http://stackoverflow.com/users/1231450/jan', 'reputation': 10280}), (559827, {'user_id': 559827, 'display_name': 'kjo', 'tags': ['python', 'matlab', 'git', 'css', 'javascript', 'pandas', 'perl', 'd3.js', 'r', 'jquery', 'numpy', 'svg', 'ocaml', 'java', 'html', 'css3', 'debugging', 'github', 'regex', 'unicode', 'shell', 'django', 'eclipse', 'emacs', 'events', 'introspection', 'ipython', 'scipy', 'unix', 'virtualenv'], 'link': 'http://stackoverflow.com/users/559827/kjo', 'reputation': 8149}), (140100, {'user_id': 140100, 'display_name': 'Night Walker ', 'tags': ['c#', '.net', 'wpf', 'sql', 'mysql', 'python', 'pandas', 'dataframe', 'xaml', 'sql-server', 'wcf', 'web-services', 'linq', 'visual-studio', 'xml', 'mvvm', 'vb.net', 'sql-server-2005', 'winforms', 'perl', 'html', 'iis', 'c++', 'data-binding', 'iis-7', 'windows', 'visual-studio-2010', 'unit-testing', 'debugging', 'asp.net'], 'link': 'http://stackoverflow.com/users/140100/night-walker', 'reputation': 6298}), (53491, {'user_id': 53491, 'display_name': 'Brian Postow', 'tags': ['o ...

# %%
profile_list = [(v[1]["user_id"],v[1]["display_name"],v[1]["reputation"],
                 v[1]["tags"],v[1]["link"]) for v in user_profile_sorted]

# %%
print(profile_list)
# Out:
# [(3510736, 'Ami Tavory', ['python', 'c++', 'pandas', 'algorithm', 'numpy', 'c++11', 'dataframe', 'scikit-learn', 'arrays', 'machine-learning', 'multithreading', 'templates', 'sorting', 'list', 'stl', 'string', 'dictionary', 'python-2.7', 'data-structures', 'scipy', 'graph', 'vector', 'csv', 'performance', 'python-3.x', 'time-complexity', 'big-o', 'class', 'tree', 'matplotlib'], 35841, 'http://stackoverflow.com/users/3510736/ami-tavory'), (2336654, 'piRSquared', ['pandas', 'python', 'dataframe', 'numpy', 'python-3.x', 'python-2.7', 'multi-index', 'datetime', 'csv', 'group-by', 'matplotlib', 'series', 'indexing', 'string', 'merge', 'dictionary', 'regex', 'scipy', 'list', 'multiple-columns', 'nan', 'pivot-table', 'scikit-learn', 'time-series', 'plot', 'performance', 'pivot', 'matrix', 'excel', 'jupyter-notebook'], 30103, 'http://stackoverflow.com/users/2336654/pirsquared'), (2411320, 'gsamaras', ['c++', 'c', 'python', 'apache-spark', 'distributed-computing', 'arrays', 'c++11', 'algorithm', 'pointers', 'html', 'string', 'nearest-neighbor', 'javascript', 'css', 'bigdata', 'function', 'linux', 'jquery', 'css3', 'mpi', 'file', 'list', 'io', 'hadoop', 'struct', 'vector', 'scala', 'machine-learning', 'computational-geometry', 'class'], 20310, 'http://stackoverflow.com/users/2411320/gsamaras'), (1179880, 'whytheq', ['mdx', 'ssas', 'sql-server', 'sql', 'excel', 'excel-vba', 'c#', 'vba', 'olap', 'reporting-services', 'tsql', 'sql-server-2008-r2', 'winforms', 'olap-cube', 'mondrian', 'python', 'sql-server-2012', 'cube', 'vb.net', 'sql-server-2008', 'visual-studio-2010', 'vim', 'javascript', 'excel-2010', 'filter', 'pandas', 'visual-studio', 'd3.js', 'ssas-2012', 'ssas-2008'], 14742, 'http://stackoverflow.com/users/1179880/whytheq'), (194000, 'Richard', ['javascript', 'python', 'django', 'd3.js', 'pandas', 'postgresql', 'css', 'jquery', 'backbone.js', 'google-bigquery', 'sql', 'git', 'angularjs', 'highcharts', 'django-rest-framework', 'github', 'twitter-bootstrap', 'node.js', 'regex', 'osx', 'google-maps', 'google-maps-api-3', 'mapbox', 'leaflet', 'matplotlib', 'html', 'browserify', 'django-models', 'google-cloud-datalab', 'json'], 11039, 'http://stackoverflow.com/users/194000/richard'), (1231450, 'Jan', ['regex', 'php', 'python', 'javascript', 'mysql', 'string', 'html', 'jquery', 'preg-replace', 'java', 'arrays', 'preg-match', 'python-3.x', 'c#', 'xml', '.htaccess', 'python-2.7', 'pandas', 'mod-rewrite', 'codeigniter', 'notepad++', 'parsing', 'wordpress', 'web-scraping', 'perl', 'redirect', 'replace', 'apache', 'forms', 'pcre'], 10280, 'http://stackoverflow.com/users/1231450/jan'), (559827, 'kjo', ['python', 'matlab', 'git', 'css', 'javascript', 'pandas', 'perl', 'd3.js', 'r', 'jquery', 'numpy', 'svg', 'ocaml', 'java', 'html', 'css3', 'debugging', 'github', 'regex', 'unicode', 'shell', 'django', 'eclipse', 'emacs', 'events', 'introspection', 'ipython', 'scipy', 'unix', 'virtualenv'], 8149, 'http://stackoverflow.com/users/559827/kjo'), (140100, 'Night Walker ', ['c#', '.net', 'wpf', 'sql', 'mysql', 'python', 'pandas', 'dataframe', 'xaml', 'sql-server', 'wcf', 'web-services', 'linq', 'visual-studio', 'xml', 'mvvm', 'vb.net', 'sql-server-2005', 'winforms', 'perl', 'html', 'iis', 'c++', 'data-binding', 'iis-7', 'windows', 'visual-studio-2010', 'unit-testing', 'debugging', 'asp.net'], 6298, 'http://stackoverflow.com/users/140100/night-walker'), (53491, 'Brian Postow', ['objective-c', 'osx', 'c++', 'c', 'python', 'cocoa', 'emacs', 'xcode', 'algorithm', 'pandas', 'nsimage', 'programming-languages', 'nsview', 'ikimageview', 'interface-builder', 'java', 'applescript', 'npapi', 'quartz-graphics', 'complexity-theory', 'dataframe', 'language-agnostic', 'core-graphics', 'browser-plugin', 'c-preprocessor', 'debugging', 'elisp', 'regex', 'theory', 'linux'], 4655, 'http://stackoverflow.com/users/53491/brian-postow'), (222151, 'cjm2671', ['ruby-on-rails', 'python', 'pandas', 'ruby', 'numpy', 'drupal', 'ruby-on-rails-3', 'python-3.x', 'jquery', 'devise', 'j ...

# %%
with open('user_reputation_sorted.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["user_id", "display_name", "reputation", "tags", "link"])
    writer.writerows(profile_list)
